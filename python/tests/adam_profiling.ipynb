# %% [markdown]
# # ADAM Profiling
#
# This notebook profiles the ADAM model to identify speed and memory bottlenecks.

# %%
import numpy as np
import cProfile
import pstats
import io
import tracemalloc
from pstats import SortKey

from smooth.adam_general.core.adam import ADAM
from smooth.adam_general.core.es import ES

# %% [markdown]
# ## Generate Test Data

# %%
# Small dataset (quick tests)
np.random.seed(42)
n_small = 120
y_small = 100 + np.cumsum(np.random.randn(n_small)) + 10 * np.sin(np.arange(n_small) * 2 * np.pi / 12)

# Medium dataset
n_medium = 500
y_medium = 100 + np.cumsum(np.random.randn(n_medium)) + 10 * np.sin(np.arange(n_medium) * 2 * np.pi / 12)

# Large dataset
n_large = 2000
y_large = 100 + np.cumsum(np.random.randn(n_large)) + 10 * np.sin(np.arange(n_large) * 2 * np.pi / 12)

print(f"Small: {n_small}, Medium: {n_medium}, Large: {n_large}")
# Out:
# Small: 120, Medium: 500, Large: 2000

# %% [markdown]
# ## 1. Speed Profiling with cProfile
#
# ### 1.1 Profile fit() method

# %%
def profile_fit(y, model_spec="AAN", lags=[1, 12], initial="backcasting", n_top=30):
    """Profile the fit method and return stats."""
    profiler = cProfile.Profile()
    
    model = ADAM(model=model_spec, lags=lags, initial=initial)
    
    profiler.enable()
    model.fit(y)
    profiler.disable()
    
    # Create stats
    s = io.StringIO()
    stats = pstats.Stats(profiler, stream=s).sort_stats(SortKey.CUMULATIVE)
    stats.print_stats(n_top)
    print(s.getvalue())
    
    return model, stats

# %%
print("=" * 80)
print("PROFILING FIT - Small dataset, AAN model")
print("=" * 80)
model_small, stats_small = profile_fit(y_small, model_spec="AAN")
# Out:
# ================================================================================
# PROFILING FIT - Small dataset, AAN model
# ================================================================================
#          9827 function calls (9803 primitive calls) in 0.023 seconds
#
#    Ordered by: cumulative time
#    List reduced from 410 to 30 due to restriction <30>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      10/8    0.000    0.000    0.029    0.004 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator.py:280(objective_wrapper)
#         2    0.000    0.000    0.012    0.006 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:14(creator)
#         2    0.000    0.000    0.012    0.006 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:686(_initialize_states)
#         2    0.000    0.000    0.012    0.006 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:770(_initialize_ets_states)
#         2    0.000    0.000    0.012    0.006 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:1139(_initialize_ets_nonseasonal_states)
#         2    0.000    0.000    0.012    0.006 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:13(msdecompose)
#         2    0.000    0.000    0.011    0.005 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:272(smoothing_function_lowess)
#         2    0.007    0.004    0.011    0.005 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/statsmodels/nonparametric/smoothers_lowess.py:12(lowess)
#        19    0.003    0.000    0.005    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/cost_functions.py:8(CF)
#      1002    0.001    0.000    0.004    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2304(sum)
#      1002    0.001    0.000    0.003    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:66(_wrapreduction)
#        19    0.000    0.000    0.002    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:572(calculate_likelihood)
#        19    0.001    0.000    0.002    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/scipy/stats/_distn_infrastructure.py:2090(logpdf)
#      1067    0.002    0.000    0.002    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       2/1    0.002    0.001    0.002    0.002 /usr/lib/python3.13/asyncio/base_events.py:1970(_run_once)
#        19    0.000    0.000    0.001    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/scipy/stats/_distn_infrastructure.py:612(argsreduce)
#         2    0.000    0.000    0.001    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:2529(architector)
#         1    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/cost_functions.py:548(log_Lik_ADAM)
#         8    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3902(median)
#         8    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3815(_ureduce)
#         8    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3991(_median)
#         1    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:957(_check_parameters)
#         1    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:1920(parameters_checker)
#        19    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:514(broadcast_arrays)
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:2902(_create_profiles)
#        85    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:2941(adam_profile_creator)
#         4    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/linalg/_linalg.py:2417(lstsq)
#        19    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:373(_broadcast_to)
#        47    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:86(_wrapreduction_any_all)

# %%
print("=" * 80)
print("PROFILING FIT - Medium dataset, AAN model")
print("=" * 80)
model_medium, stats_medium = profile_fit(y_medium, model_spec="AAN")
# Out:
# ================================================================================
# PROFILING FIT - Medium dataset, AAN model
# ================================================================================
#          29254 function calls (29216 primitive calls) in 0.079 seconds
#
#    Ordered by: cumulative time
#    List reduced from 484 to 30 due to restriction <30>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         9    0.004    0.000    0.067    0.007 /usr/lib/python3.13/asyncio/base_events.py:1970(_run_once)
#         2    0.006    0.003    0.064    0.032 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:14(creator)
#         2    0.000    0.000    0.058    0.029 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:686(_initialize_states)
#         4    0.000    0.000    0.041    0.010 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator.py:280(objective_wrapper)
#       9/6    0.000    0.000    0.035    0.006 /usr/lib/python3.13/asyncio/events.py:87(_run)
#         2    0.000    0.000    0.031    0.016 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:770(_initialize_ets_states)
#         2    0.000    0.000    0.031    0.016 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:1139(_initialize_ets_nonseasonal_states)
#         2    0.000    0.000    0.031    0.016 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:13(msdecompose)
#         2    0.000    0.000    0.026    0.013 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:272(smoothing_function_lowess)
#       9/6    0.000    0.000    0.025    0.004 {method 'run' of '_contextvars.Context' objects}
#         2    0.011    0.005    0.018    0.009 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/statsmodels/nonparametric/smoothers_lowess.py:12(lowess)
#         8    0.000    0.000    0.016    0.002 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3902(median)
#         8    0.000    0.000    0.016    0.002 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3815(_ureduce)
#      4042    0.003    0.000    0.016    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2304(sum)
#         1    0.000    0.000    0.016    0.016 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/decorator.py:232(fun)
#         1    0.000    0.000    0.016    0.016 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/IPython/core/history.py:54(only_when_enabled)
#         1    0.000    0.000    0.016    0.016 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/IPython/core/history.py:836(writeout_cache)
#         1    0.000    0.000    0.015    0.015 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/IPython/core/history.py:824(_writeout_input_cache)
#         2    0.004    0.002    0.015    0.008 {method '__exit__' of 'sqlite3.Connection' objects}
#       9/6    0.000    0.000    0.015    0.003 /usr/lib/python3.13/selectors.py:435(select)
#      4042    0.004    0.000    0.012    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:66(_wrapreduction)
#        19    0.009    0.000    0.011    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/cost_functions.py:8(CF)
#         6    0.006    0.001    0.009    0.002 /usr/lib/python3.13/asyncio/selector_events.py:961(_read_ready)
#      4107    0.008    0.000    0.008    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         2    0.000    0.000    0.008    0.004 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/ipykernel/iostream.py:276(<lambda>)
#         2    0.005    0.003    0.007    0.004 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/ipykernel/iostream.py:278(_really_send)
#         3    0.000    0.000    0.003    0.001 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/x64/cp313/zmq/eventloop/zmqstream.py:573(_handle_events)
#         1    0.000    0.000    0.003    0.003 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/x64/cp3/tornado/platform/asyncio.py:206(_handle_events)
#         3    0.000    0.000    0.003    0.001 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/x64/cp313/zmq/eventloop/zmqstream.py:614(_handle_recv)
#         3    0.002    0.001    0.003    0.001 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/x64/cp313/zmq/eventloop/zmqstream.py:546(_run_callback)

# %%
print("=" * 80)
print("PROFILING FIT - Model Selection (ZZZ)")
print("=" * 80)
model_select, stats_select = profile_fit(y_small, model_spec="ZZZ")
# Out:
# ================================================================================
# PROFILING FIT - Model Selection (ZZZ)
# ================================================================================
#          382735 function calls (382353 primitive calls) in 0.854 seconds
#
#    Ordered by: cumulative time
#    List reduced from 630 to 30 due to restriction <30>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1628    0.253    0.000    0.421    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/cost_functions.py:8(CF)
#        19    0.000    0.000    0.361    0.019 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:14(creator)
#        19    0.000    0.000    0.360    0.019 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:686(_initialize_states)
#        19    0.000    0.000    0.360    0.019 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:770(_initialize_ets_states)
#        31    0.005    0.000    0.359    0.012 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:13(msdecompose)
#       295    0.003    0.000    0.359    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:272(smoothing_function_lowess)
#       295    0.213    0.001    0.352    0.001 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/statsmodels/nonparametric/smoothers_lowess.py:12(lowess)
#        13    0.000    0.000    0.305    0.023 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:849(_initialize_ets_seasonal_states_with_decomp)
#      1438    0.004    0.000    0.138    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:572(calculate_likelihood)
#      1438    0.045    0.000    0.132    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/scipy/stats/_distn_infrastructure.py:2090(logpdf)
#     28422    0.023    0.000    0.106    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2304(sum)
#     28425    0.028    0.000    0.080    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:66(_wrapreduction)
#     34409    0.062    0.000    0.062    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         6    0.000    0.000    0.055    0.009 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:1139(_initialize_ets_nonseasonal_states)
#      1438    0.007    0.000    0.046    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/scipy/stats/_distn_infrastructure.py:612(argsreduce)
#    317/11    0.002    0.000    0.045    0.004 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator.py:280(objective_wrapper)
#      1180    0.001    0.000    0.043    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3902(median)
#      1180    0.002    0.000    0.042    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3815(_ureduce)
#      1180    0.007    0.000    0.039    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3991(_median)
#      1438    0.004    0.000    0.024    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:514(broadcast_arrays)
#       9/2    0.000    0.000    0.020    0.010 /usr/lib/python3.13/asyncio/events.py:87(_run)
#      11/2    0.002    0.000    0.020    0.010 {method 'run' of '_contextvars.Context' objects}
#      1628    0.018    0.000    0.020    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:3011(filler)
#       5/1    0.000    0.000    0.019    0.019 /usr/lib/python3.13/asyncio/base_events.py:1970(_run_once)
#      1438    0.011    0.000    0.015    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:373(_broadcast_to)
#      1438    0.005    0.000    0.014    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/utils.py:665(scaler)
#         1    0.000    0.000    0.014    0.014 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:1302(_execute_estimation)
#         5    0.000    0.000    0.014    0.003 /usr/share/positron/resources/app/extensions/positron-python/python_files/posit/positron/positron_jedilsp.py:306(_data_received)
#      8971    0.013    0.000    0.014    0.000 {built-in method builtins.any}
#         3    0.000    0.000    0.014    0.005 /usr/share/positron/resources/app/extensions/positron-python/python_files/posit/positron/_vendor/pygls/protocol/json_rpc.py:350(_procedure_handler)

# %% [markdown]
# ### 1.2 Profile predict() method

# %%
def profile_predict(model, h=12, n_top=30):
    """Profile the predict method."""
    profiler = cProfile.Profile()
    
    profiler.enable()
    forecast = model.predict(h=h)
    profiler.disable()
    
    s = io.StringIO()
    stats = pstats.Stats(profiler, stream=s).sort_stats(SortKey.CUMULATIVE)
    stats.print_stats(n_top)
    print(s.getvalue())
    
    return forecast, stats

# %%
print("=" * 80)
print("PROFILING PREDICT")
print("=" * 80)
forecast, pred_stats = profile_predict(model_small, h=12)
# Out:
# ================================================================================
# PROFILING PREDICT
# ================================================================================
#          3253 function calls (3208 primitive calls) in 0.005 seconds
#
#    Ordered by: cumulative time
#    List reduced from 430 to 30 due to restriction <30>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.002    0.002 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/decorator.py:232(fun)
#         1    0.000    0.000    0.002    0.002 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/IPython/core/history.py:54(only_when_enabled)
#         1    0.000    0.000    0.002    0.002 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/IPython/core/history.py:836(writeout_cache)
#         1    0.000    0.000    0.002    0.002 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/IPython/core/history.py:824(_writeout_input_cache)
#         1    0.000    0.000    0.002    0.002 /usr/lib/python3.13/asyncio/events.py:87(_run)
#         1    0.000    0.000    0.002    0.002 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.002    0.002 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/x64/cp3/tornado/platform/asyncio.py:206(_handle_events)
#         1    0.000    0.000    0.002    0.002 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/x64/cp313/zmq/eventloop/zmqstream.py:573(_handle_events)
#         1    0.000    0.000    0.002    0.002 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/x64/cp313/zmq/eventloop/zmqstream.py:614(_handle_recv)
#         1    0.000    0.000    0.002    0.002 /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/x64/cp313/zmq/eventloop/zmqstream.py:546(_run_callback)
#         1    0.000    0.000    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:804(predict)
#       2/1    0.001    0.000    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:1741(_execute_prediction)
#         1    0.000    0.000    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/forecaster.py:544(forecaster)
#         1    0.000    0.000    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/forecaster.py:1993(generate_prediction_interval)
#         1    0.000    0.000    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:1696(_prepare_prediction_data)
#         1    0.000    0.000    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/forecaster.py:1491(preparator)
#         1    0.000    0.000    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/var_covar.py:5(sigma)
#         1    0.000    0.000    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/forecaster.py:300(_generate_point_forecasts)
#         1    0.001    0.001    0.001    0.001 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/utils/var_covar.py:203(covar_anal)
#         8    0.000    0.000    0.001    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/series.py:392(__init__)
#         1    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/forecaster.py:1378(_calculate_scale_parameter)
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/scipy/stats/_distn_infrastructure.py:2302(ppf)
#         3    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/series.py:1107(__getitem__)
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/ops/common.py:62(new_method)
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/arraylike.py:240(__pow__)
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/series.py:6152(_arith_method)
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/series.py:6540(sum)
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/base.py:1380(_arith_method)
#         1    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/forecaster.py:186(_prepare_lookup_table)
#         2    0.000    0.000    0.000    0.000 /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/generic.py:12563(sum)

# %% [markdown]
# ### 1.3 Profile by function category

# %%
def profile_fit_detailed(y, model_spec="AAN", lags=[1, 12], initial="backcasting"):
    """Profile fit with detailed breakdown by module."""
    profiler = cProfile.Profile()
    
    model = ADAM(model=model_spec, lags=lags, initial=initial)
    
    profiler.enable()
    model.fit(y)
    profiler.disable()
    
    stats = pstats.Stats(profiler)
    
    # Group by module
    modules = {
        'checker': 0,
        'creator': 0,
        'estimator': 0,
        'forecaster': 0,
        'cost_functions': 0,
        'utils': 0,
        '_adam_general': 0,  # C++ code
        'nlopt': 0,
        'numpy': 0,
        'other': 0
    }
    
    for (filename, line, func), (cc, nc, tt, ct, callers) in stats.stats.items():
        categorized = False
        for module in modules:
            if module in filename:
                modules[module] += ct
                categorized = True
                break
        if not categorized:
            modules['other'] += ct
    
    total = sum(modules.values())
    print("\nTime by module:")
    print("-" * 50)
    for module, time in sorted(modules.items(), key=lambda x: -x[1]):
        pct = 100 * time / total if total > 0 else 0
        print(f"{module:20s}: {time:8.4f}s ({pct:5.1f}%)")
    
    return model, stats

# %%
print("=" * 80)
print("TIME BREAKDOWN BY MODULE - Small dataset")
print("=" * 80)
_, _ = profile_fit_detailed(y_small)
# Out:
# ================================================================================
# TIME BREAKDOWN BY MODULE - Small dataset
# ================================================================================
#
# Time by module:
# --------------------------------------------------
# other               :   0.0749s ( 39.8%)
# creator             :   0.0525s ( 27.9%)
# utils               :   0.0275s ( 14.6%)
# estimator           :   0.0160s (  8.5%)
# numpy               :   0.0108s (  5.7%)
# cost_functions      :   0.0054s (  2.9%)
# checker             :   0.0007s (  0.4%)
# nlopt               :   0.0001s (  0.0%)
# forecaster          :   0.0000s (  0.0%)
# _adam_general       :   0.0000s (  0.0%)

# %%
print("=" * 80)
print("TIME BREAKDOWN BY MODULE - Medium dataset")
print("=" * 80)
_, _ = profile_fit_detailed(y_medium)
# Out:
# ================================================================================
# TIME BREAKDOWN BY MODULE - Medium dataset
# ================================================================================
#
# Time by module:
# --------------------------------------------------
# other               :   0.4814s ( 75.5%)
# creator             :   0.0655s ( 10.3%)
# numpy               :   0.0401s (  6.3%)
# utils               :   0.0332s (  5.2%)
# cost_functions      :   0.0114s (  1.8%)
# estimator           :   0.0039s (  0.6%)
# checker             :   0.0020s (  0.3%)
# nlopt               :   0.0001s (  0.0%)
# forecaster          :   0.0000s (  0.0%)
# _adam_general       :   0.0000s (  0.0%)

# %% [markdown]
# ## 2. Memory Profiling with tracemalloc

# %%
def profile_memory(y, model_spec="AAN", lags=[1, 12], initial="backcasting", n_top=20):
    """Profile memory usage during fit."""
    tracemalloc.start()
    
    model = ADAM(model=model_spec, lags=lags, initial=initial)
    model.fit(y)
    
    snapshot = tracemalloc.take_snapshot()
    tracemalloc.stop()
    
    # Top memory consumers by line
    print(f"\nTop {n_top} memory allocations by line:")
    print("-" * 80)
    top_stats = snapshot.statistics('lineno')
    for stat in top_stats[:n_top]:
        print(stat)
    
    # Top memory consumers by file
    print(f"\nTop {n_top} memory allocations by file:")
    print("-" * 80)
    top_stats = snapshot.statistics('filename')
    for stat in top_stats[:n_top]:
        print(stat)
    
    return model, snapshot

# %%
print("=" * 80)
print("MEMORY PROFILING - Small dataset")
print("=" * 80)
_, snapshot_small = profile_memory(y_small)
# Out:
# ================================================================================
# MEMORY PROFILING - Small dataset
# ================================================================================
#
# Top 20 memory allocations by line:
# --------------------------------------------------------------------------------
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_arraysetops_impl.py:358: size=4192 B, count=8, average=524 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator.py:356: size=2200 B, count=7, average=314 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:3006: size=2032 B, count=2, average=1016 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:385: size=2032 B, count=2, average=1016 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:232: size=2016 B, count=2, average=1008 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:465: size=1520 B, count=1, average=1520 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:1732: size=1056 B, count=2, average=528 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:1656: size=1056 B, count=2, average=528 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:391: size=686 B, count=14, average=49 B
# /usr/lib/python3.13/json/decoder.py:361: size=652 B, count=9, average=72 B
# /usr/lib/python3.13/json/decoder.py:337: size=581 B, count=11, average=53 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2708: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2691: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2672: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2657: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2619: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2602: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:1849: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_utils_impl.py:680: size=352 B, count=8, average=44 B
# <cattrs generated structure positron._vendor.lsprotocol.types.NotebookCell>:28: size=320 B, count=3, average=107 B
#
# Top 20 memory allocations by file:
# --------------------------------------------------------------------------------
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:0: size=5486 B, count=22, average=249 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_arraysetops_impl.py:0: size=4272 B, count=11, average=388 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:0: size=4264 B, count=6, average=711 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:0: size=2680 B, count=12, average=223 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator.py:0: size=2408 B, count=8, average=301 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:0: size=1873 B, count=5, average=375 B
# /usr/lib/python3.13/json/decoder.py:0: size=1233 B, count=20, average=62 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:0: size=686 B, count=14, average=49 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/scipy/stats/_distn_infrastructure.py:0: size=448 B, count=10, average=45 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_utils_impl.py:0: size=352 B, count=8, average=44 B
# /usr/lib/python3.13/asyncio/base_events.py:0: size=336 B, count=4, average=84 B
# <cattrs generated structure positron._vendor.lsprotocol.types.NotebookCell>:0: size=320 B, count=3, average=107 B
# /tmp/ipykernel_697470/4282579739.py:0: size=320 B, count=1, average=320 B
# <cattrs generated structure positron._vendor.lsprotocol.types.NotebookDocumentDidChangeNotification>:0: size=312 B, count=3, average=104 B
# <cattrs generated structure positron._vendor.lsprotocol.types.NotebookDocumentChangeEventCellsType>:0: size=312 B, count=3, average=104 B
# <cattrs generated structure positron._vendor.lsprotocol.types.NotebookDocumentChangeEvent>:0: size=304 B, count=3, average=101 B
# /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/ipykernel/iostream.py:0: size=288 B, count=4, average=72 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:0: size=280 B, count=4, average=70 B
# /usr/share/positron/resources/app/extensions/positron-python/python_files/lib/ipykernel/py3/traitlets/traitlets.py:0: size=249 B, count=4, average=62 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/generic.py:0: size=232 B, count=3, average=77 B

# %%
print("=" * 80)
print("MEMORY PROFILING - Large dataset")
print("=" * 80)
_, snapshot_large = profile_memory(y_large)
# Out:
# ================================================================================
# MEMORY PROFILING - Large dataset
# ================================================================================
#
# Top 20 memory allocations by line:
# --------------------------------------------------------------------------------
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_arraysetops_impl.py:358: size=62.8 KiB, count=8, average=8044 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:3006: size=31.4 KiB, count=2, average=15.7 KiB
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:385: size=31.4 KiB, count=2, average=15.7 KiB
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:232: size=31.3 KiB, count=2, average=15.7 KiB
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:1732: size=15.7 KiB, count=2, average=8048 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:1656: size=15.7 KiB, count=2, average=8048 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator.py:356: size=2200 B, count=7, average=314 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:310: size=2096 B, count=2, average=1048 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:465: size=1520 B, count=1, average=1520 B
# /usr/lib/python3.13/json/decoder.py:337: size=1251 B, count=24, average=52 B
# /usr/lib/python3.13/json/decoder.py:361: size=948 B, count=13, average=73 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:391: size=833 B, count=17, average=49 B
# <cattrs generated structure positron._vendor.lsprotocol.types.Position>:16: size=488 B, count=5, average=98 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2708: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2691: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2672: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2657: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2619: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:2602: size=400 B, count=1, average=400 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:1849: size=400 B, count=1, average=400 B
#
# Top 20 memory allocations by file:
# --------------------------------------------------------------------------------
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:0: size=64.8 KiB, count=6, average=10.8 KiB
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_arraysetops_impl.py:0: size=62.9 KiB, count=10, average=6438 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/checker.py:0: size=34.8 KiB, count=26, average=1372 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/creator.py:0: size=32.0 KiB, count=13, average=2522 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/estimator.py:0: size=2408 B, count=8, average=301 B
# /usr/lib/python3.13/json/decoder.py:0: size=2199 B, count=37, average=59 B
# /home/config/Python/Libraries/smooth/python/src/smooth/adam_general/core/adam.py:0: size=1913 B, count=6, average=319 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:0: size=833 B, count=17, average=49 B
# /usr/lib/python3.13/asyncio/base_events.py:0: size=712 B, count=9, average=79 B
# <cattrs generated structure positron._vendor.lsprotocol.types.Position>:0: size=488 B, count=5, average=98 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/scipy/stats/_distn_infrastructure.py:0: size=448 B, count=10, average=45 B
# <cattrs generated structure positron._vendor.lsprotocol.types.ExecutionSummary>:0: size=368 B, count=4, average=92 B
# <cattrs generated structure positron._vendor.lsprotocol.types.DidChangeNotebookDocumentParams>:0: size=368 B, count=4, average=92 B
# <cattrs generated structure positron._vendor.lsprotocol.types.NotebookCell>:0: size=320 B, count=3, average=107 B
# /tmp/ipykernel_697470/4282579739.py:0: size=320 B, count=1, average=320 B
# <cattrs generated structure positron._vendor.lsprotocol.types.NotebookDocumentChangeEventCellsType>:0: size=312 B, count=3, average=104 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/numpy/lib/_utils_impl.py:0: size=308 B, count=7, average=44 B
# <cattrs generated structure positron._vendor.lsprotocol.types.VersionedNotebookDocumentIdentifier>:0: size=304 B, count=3, average=101 B
# <cattrs generated structure positron._vendor.lsprotocol.types.NotebookDocumentChangeEvent>:0: size=304 B, count=3, average=101 B
# /home/config/Python/Libraries/smooth/python/.venv/lib/python3.13/site-packages/pandas/core/internals/managers.py:0: size=300 B, count=5, average=60 B

# %% [markdown]
# ## 3. Timing Individual Components

# %%
import time

def time_components(y, model_spec="AAN", lags=[1, 12], initial="backcasting"):
    """Time individual components of the fitting process."""
    from smooth.adam_general.core.checker import parameters_checker
    from smooth.adam_general.core.creator import architector, creator, initialiser
    from smooth.adam_general.core.estimator import estimator
    
    timings = {}
    
    # Create model instance
    model = ADAM(model=model_spec, lags=lags, initial=initial)
    
    # Time parameters_checker
    start = time.perf_counter()
    checked = parameters_checker(
        data=y,
        model=model.model,
        lags=model.lags,
        constant=model.constant,
        outliers=model.outliers,
        occurrence=model.occurrence,
        distribution=model.distribution,
        loss=model.loss,
        h=model.h,
        holdout=model.holdout,
        persistence=model.persistence,
        phi=model.phi,
        initial=model.initial,
        arma=model.arma,
        ic=model.ic,
        bounds=model.bounds,
        regressors=model.regressors,
        X=None
    )
    timings['parameters_checker'] = time.perf_counter() - start
    
    # Time architector
    start = time.perf_counter()
    arch = architector(
        model_type_dict=checked['model_type_dict'],
        lags_dict=checked['lags_dict'],
        observations_dict=checked['observations_dict'],
        persistence_checked=checked['persistence_checked'],
        initials_checked=checked['initials_checked'],
        arima_checked=checked['arima_checked'],
        explanatory_checked=checked['explanatory_dict'],
        phi_dict=checked['phi_dict'],
        constants_checked=checked['constant_dict'],
        profiles_recent_table=None
    )
    timings['architector'] = time.perf_counter() - start
    
    # Time creator
    start = time.perf_counter()
    created = creator(
        model_type_dict=checked['model_type_dict'],
        lags_dict=checked['lags_dict'],
        profiles_dict=arch['profiles_dict'],
        observations_dict=checked['observations_dict'],
        components_dict=arch['components_dict'],
        persistence_checked=checked['persistence_checked'],
        phi_dict=checked['phi_dict'],
        initials_checked=checked['initials_checked'],
        arima_checked=checked['arima_checked'],
        constants_checked=checked['constant_dict'],
        explanatory_checked=checked['explanatory_dict']
    )
    timings['creator'] = time.perf_counter() - start
    
    # Time initialiser
    start = time.perf_counter()
    init = initialiser(
        model_type_dict=checked['model_type_dict'],
        lags_dict=checked['lags_dict'],
        profiles_dict=arch['profiles_dict'],
        components_dict=arch['components_dict'],
        observations_dict=checked['observations_dict'],
        persistence_checked=checked['persistence_checked'],
        initials_checked=checked['initials_checked'],
        arima_checked=checked['arima_checked'],
        explanatory_checked=checked['explanatory_dict'],
        phi_dict=checked['phi_dict'],
        constants_checked=checked['constant_dict'],
        general=checked['general'],
        adam_created=created
    )
    timings['initialiser'] = time.perf_counter() - start
    
    # Time estimator
    start = time.perf_counter()
    est = estimator(
        y=checked['observations_dict']['y_in_sample'],
        model_type_dict=checked['model_type_dict'],
        lags_dict=checked['lags_dict'],
        profiles_dict=arch['profiles_dict'],
        components_dict=arch['components_dict'],
        observations_dict=checked['observations_dict'],
        persistence_checked=checked['persistence_checked'],
        initials_checked=checked['initials_checked'],
        arima_checked=checked['arima_checked'],
        explanatory_checked=checked['explanatory_dict'],
        phi_dict=checked['phi_dict'],
        constants_checked=checked['constant_dict'],
        general=checked['general'],
        adam_created=created,
        B=init['B'],
        Bl=init['Bl'],
        Bu=init['Bu']
    )
    timings['estimator'] = time.perf_counter() - start
    
    # Print results
    total = sum(timings.values())
    print("\nComponent timings:")
    print("-" * 50)
    for name, t in sorted(timings.items(), key=lambda x: -x[1]):
        pct = 100 * t / total if total > 0 else 0
        print(f"{name:20s}: {t:8.4f}s ({pct:5.1f}%)")
    print("-" * 50)
    print(f"{'TOTAL':20s}: {total:8.4f}s")
    
    return timings

# %%
print("=" * 80)
print("COMPONENT TIMINGS - Small dataset")
print("=" * 80)
timings_small = time_components(y_small)
# Out:
# ================================================================================
# COMPONENT TIMINGS - Small dataset
# ================================================================================
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[22], line 4
#
#       2 print("COMPONENT TIMINGS - Small dataset")
#
#       3 print("=" * 80)
#
# ----> 4 timings_small = time_components(y_small)
#
#
#
# Cell In[21], line 16, in time_components(y, model_spec, lags, initial)
#
#      14 # Time parameters_checker
#
#      15 start = time.perf_counter()
#
# ---> 16 checked = parameters_checker(
#
#      17     y=y,
#
#      18     model=model.model,
#
#      19     lags=model.lags,
#
#      20     constant=model.constant,
#
#      21     outliers=model.outliers,
#
#      22     occurrence=model.occurrence,
#
#      23     distribution=model.distribution,
#
#      24     loss=model.loss,
#
#      25     h=model.h,
#
#      26     holdout=model.holdout,
#
#      27     persistence=model.persistence,
#
#      28     phi=model.phi,
#
#      29     initial=model.initial,
#
#      30     arma=model.arma,
#
#      31     ic=model.ic,
#
#      32     bounds=model.bounds,
#
#      33     regressors=model.regressors,
#
#      34     X=None
#
#      35 )
#
#      36 timings['parameters_checker'] = time.perf_counter() - start
#
#      38 # Time architector
#
#
#
# TypeError: parameters_checker() got an unexpected keyword argument 'y'

# %%
print("=" * 80)
print("COMPONENT TIMINGS - Medium dataset")
print("=" * 80)
timings_medium = time_components(y_medium)
# Out:
# ================================================================================
# COMPONENT TIMINGS - Medium dataset
# ================================================================================
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[24], line 4
#
#       2 print("COMPONENT TIMINGS - Medium dataset")
#
#       3 print("=" * 80)
#
# ----> 4 timings_medium = time_components(y_medium)
#
#
#
# Cell In[23], line 16, in time_components(y, model_spec, lags, initial)
#
#      14 # Time parameters_checker
#
#      15 start = time.perf_counter()
#
# ---> 16 checked = parameters_checker(
#
#      17     data=y,
#
#      18     model=model.model,
#
#      19     lags=model.lags,
#
#      20     constant=model.constant,
#
#      21     outliers=model.outliers,
#
#      22     occurrence=model.occurrence,
#
#      23     distribution=model.distribution,
#
#      24     loss=model.loss,
#
#      25     h=model.h,
#
#      26     holdout=model.holdout,
#
#      27     persistence=model.persistence,
#
#      28     phi=model.phi,
#
#      29     initial=model.initial,
#
#      30     arma=model.arma,
#
#      31     ic=model.ic,
#
#      32     bounds=model.bounds,
#
#      33     regressors=model.regressors,
#
#      34     X=None
#
#      35 )
#
#      36 timings['parameters_checker'] = time.perf_counter() - start
#
#      38 # Time architector
#
#
#
# TypeError: parameters_checker() got an unexpected keyword argument 'arma'

# %%
print("=" * 80)
print("COMPONENT TIMINGS - Large dataset")
print("=" * 80)
timings_large = time_components(y_large)

# %% [markdown]
# ## 4. Optimization Iterations Profiling

# %%
def profile_cost_function(y, model_spec="AAN", lags=[1, 12], initial="backcasting", n_calls=100):
    """Profile the cost function that's called during optimization."""
    from smooth.adam_general.core.checker import parameters_checker
    from smooth.adam_general.core.creator import architector, creator, initialiser, filler
    from smooth.adam_general.core.utils.cost_functions import CF
    
    # Setup model
    model = ADAM(model=model_spec, lags=lags, initial=initial)
    
    checked = parameters_checker(
        y=y, model=model.model, lags=model.lags, orders=model.orders,
        constant=model.constant, formula=model.formula, outliers=model.outliers,
        level=model.level, occurrence=model.occurrence, distribution=model.distribution,
        loss=model.loss, h=model.h, holdout=model.holdout, persistence=model.persistence,
        phi=model.phi, initial=model.initial, arma=model.arma, ic=model.ic,
        bounds=model.bounds, regressors=model.regressors, X=None
    )
    
    arch = architector(
        model_type_dict=checked['model_type_dict'],
        lags_dict=checked['lags_dict'],
        observations_dict=checked['observations_dict'],
        persistence_checked=checked['persistence_checked'],
        initials_checked=checked['initials_checked'],
        arima_checked=checked['arima_checked'],
        explanatory_checked=checked['explanatory_dict'],
        phi_dict=checked['phi_dict'],
        constants_checked=checked['constant_dict'],
        profiles_recent_table=None
    )
    
    created = creator(
        model_type_dict=checked['model_type_dict'],
        lags_dict=checked['lags_dict'],
        profiles_dict=arch['profiles_dict'],
        observations_dict=checked['observations_dict'],
        components_dict=arch['components_dict'],
        persistence_checked=checked['persistence_checked'],
        phi_dict=checked['phi_dict'],
        initials_checked=checked['initials_checked'],
        arima_checked=checked['arima_checked'],
        constants_checked=checked['constant_dict'],
        explanatory_checked=checked['explanatory_dict']
    )
    
    init = initialiser(
        model_type_dict=checked['model_type_dict'],
        lags_dict=checked['lags_dict'],
        profiles_dict=arch['profiles_dict'],
        components_dict=arch['components_dict'],
        observations_dict=checked['observations_dict'],
        persistence_checked=checked['persistence_checked'],
        initials_checked=checked['initials_checked'],
        arima_checked=checked['arima_checked'],
        explanatory_checked=checked['explanatory_dict'],
        phi_dict=checked['phi_dict'],
        constants_checked=checked['constant_dict'],
        general=checked['general'],
        adam_created=created
    )
    
    B = init['B']
    
    # Time single CF call
    start = time.perf_counter()
    for _ in range(n_calls):
        CF(
            B=B,
            model_type_dict=checked['model_type_dict'],
            lags_dict=checked['lags_dict'],
            profiles_dict=arch['profiles_dict'],
            components_dict=arch['components_dict'],
            observations_dict=checked['observations_dict'],
            persistence_checked=checked['persistence_checked'],
            initials_checked=checked['initials_checked'],
            arima_checked=checked['arima_checked'],
            explanatory_checked=checked['explanatory_dict'],
            phi_dict=checked['phi_dict'],
            constants_checked=checked['constant_dict'],
            general=checked['general'],
            adam_created=created
        )
    elapsed = time.perf_counter() - start
    
    print(f"\nCost function timing ({n_calls} calls):")
    print(f"  Total time: {elapsed:.4f}s")
    print(f"  Per call:   {elapsed/n_calls*1000:.4f}ms")
    print(f"  Calls/sec:  {n_calls/elapsed:.1f}")
    
    # Profile single call
    print(f"\nDetailed profile of single CF call:")
    profiler = cProfile.Profile()
    profiler.enable()
    CF(
        B=B,
        model_type_dict=checked['model_type_dict'],
        lags_dict=checked['lags_dict'],
        profiles_dict=arch['profiles_dict'],
        components_dict=arch['components_dict'],
        observations_dict=checked['observations_dict'],
        persistence_checked=checked['persistence_checked'],
        initials_checked=checked['initials_checked'],
        arima_checked=checked['arima_checked'],
        explanatory_checked=checked['explanatory_dict'],
        phi_dict=checked['phi_dict'],
        constants_checked=checked['constant_dict'],
        general=checked['general'],
        adam_created=created
    )
    profiler.disable()
    
    s = io.StringIO()
    stats = pstats.Stats(profiler, stream=s).sort_stats(SortKey.CUMULATIVE)
    stats.print_stats(20)
    print(s.getvalue())
    
    return elapsed / n_calls

# %%
print("=" * 80)
print("COST FUNCTION PROFILING - Small dataset")
print("=" * 80)
cf_time_small = profile_cost_function(y_small, n_calls=100)

# %%
print("=" * 80)
print("COST FUNCTION PROFILING - Large dataset")
print("=" * 80)
cf_time_large = profile_cost_function(y_large, n_calls=100)

# %% [markdown]
# ## 5. Comparison: Different Model Configurations

# %%
def benchmark_configurations(y, configs):
    """Benchmark different model configurations."""
    results = []
    
    for name, config in configs.items():
        model = ADAM(**config)
        
        # Time fit
        start = time.perf_counter()
        model.fit(y)
        fit_time = time.perf_counter() - start
        
        # Time predict
        start = time.perf_counter()
        model.predict(h=12)
        predict_time = time.perf_counter() - start
        
        results.append({
            'name': name,
            'fit_time': fit_time,
            'predict_time': predict_time,
            'total_time': fit_time + predict_time
        })
        
        print(f"{name:30s}: fit={fit_time:.3f}s, predict={predict_time:.3f}s")
    
    return results

# %%
configs = {
    'ANN (simple)': {'model': 'ANN', 'lags': [1], 'initial': 'backcasting'},
    'AAN (trend)': {'model': 'AAN', 'lags': [1], 'initial': 'backcasting'},
    'ANA (seasonal)': {'model': 'ANA', 'lags': [1, 12], 'initial': 'backcasting'},
    'AAA (full)': {'model': 'AAA', 'lags': [1, 12], 'initial': 'backcasting'},
    'MAM (multiplicative)': {'model': 'MAM', 'lags': [1, 12], 'initial': 'backcasting'},
    'ZZZ (selection)': {'model': 'ZZZ', 'lags': [1, 12], 'initial': 'backcasting'},
}

print("=" * 80)
print("BENCHMARK CONFIGURATIONS - Small dataset")
print("=" * 80)
results = benchmark_configurations(y_small, configs)

# %% [markdown]
# ## 6. Summary and Recommendations

# %%
print("=" * 80)
print("PROFILING SUMMARY")
print("=" * 80)
print("""
Key findings from profiling:

1. SPEED BOTTLENECKS:
   - Check the 'estimator' timing - this includes optimization
   - The cost function (CF) is called many times during optimization
   - filler() is called inside CF and can be slow if not optimized
   - C++ adam_fitter should be fast; if Python overhead is high, look at data conversion

2. MEMORY BOTTLENECKS:
   - Large matrices (mat_vt, mat_wt, mat_f) can consume memory
   - Check for unnecessary copies of arrays
   - Model selection (ZZZ) fits multiple models, multiplying memory usage

3. OPTIMIZATION TARGETS:
   - Reduce dictionary lookups in hot paths
   - Pre-allocate arrays instead of creating new ones
   - Consider caching repeated calculations
   - Ensure numpy operations are vectorized

Run the cells above to identify specific bottlenecks in your environment.
""")
